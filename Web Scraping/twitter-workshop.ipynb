# %% [markdown]
# # Scraping Twitter with Python

# %% [markdown]
# ### Download Sublime Text

# %% [markdown]
# For this workshop, you will need a decent, cross-platform text editor. I recommend installing [Sublime Text 3](www.sublimetext.com/3). Just surf to the download tab and install the editor.

# %% [markdown]
# ## Scraping Twitter

# %% [markdown]
# Ever since the launch of Twitter in 2006, researchers from various disciplines (e.g. Sociology, Linguistics, Computer Science, Folklore, etc.) have been interested in the social networking service. The service gained worldwide popularity, and nowadays, Twitter has more than 500 million registered users, out of which about 332 million are active. Every second, about 6000 tweets are produced on Twitter, which corresponds to 360,000 tweets per minute, about 518 million tweets per day and around 200 billion tweets per year. As such, Twitter hosts a massive amount of accessible messages, which in turn harbor vast amounts of information about numerous subjects and topics.
# <br/><br/>
# The massive amounts of data require new tools, such as robust data-retrieval and data-mining methods, that can be employed to efficiently analyze the Twitter stream. In this workshop, we will create a small application to automatically 'scrape' large amounts of tweets from Twitter. In order to efficiently analyze these large amounts of tweets, we need tools to automatically convert the tweets in a more accessible and user-friendly format. Therefore, the second part of this workshop will be devoted to creating another application, which allows us to preprocess the data for doing textual analysis. Finally, in the third and last part of this workshop, we will start digging into some basic techniques for visualizing our data.

# %% [markdown]
# ## Setting up Twitter

# %% [markdown]
# Now that we have seen some very basic computer code, it is time to start working on our Twitter scraping application. Twitter allows developers to access a small part of the complete Twitter stream by means of their provided Application Programming Interface (API). However, this stream is only accessible through authorized requests to the Twitter API. This means that we need to register our application at Twitter, which will provide us with the necessary access codes and passwords. Setting up the Twitter application involves the following XX steps:

# %% [markdown]
# ### 1. Register as a Twitter user

# %% [markdown]
# Only registered users of Twitter can create applications. Our first step, therefore, is to create a Twitter account. Please visit the website of [Twitter](https://twitter.com/) and if you do not have account yet, please create one.

# %% [markdown]
# ### 2. Register your application

# %% [markdown]
# In order to have access to Twitter data programmatically, we need to create an application which interacts with the Twitter API. To create this application, first visit the website [https://apps.twitter.com/](https://apps.twitter.com/), login to Twitter (if you're not already logged in), and click the button which says "Create New App":

# %% [markdown]
# ![](images/twitter-app-create.png)

# %% [markdown]
# In the next step, you need to fill in the various required fields. First, give your application a new name, for example `lastname-scraper` (where you replace `lastname` with your own last name). Second, Provide a small description of your application (you can write whatever you like). Third, make up an web-address where your application is supposedly hosted (e.g. `http://www.lastname-scraper.nl`). Finally, agree with the "Developer Agreement" and press "Create your Twitter Application":

# %% [markdown]
# ![](images/twitter-app-info.png)

# %% [markdown]
# After you have created your application, you will receive a "consumer key" and a "consumer secret". These "passwords" are application settings that should be kept private at all costs! In the next step, go to the tab called "Keys and Access Tokens" of your application:

# %% [markdown]
# ![](images/twitter-key-access.png)

# %% [markdown]
# Scroll down and click on the button which says "Generate Access Token and Token Secret".

# %% [markdown]
# ## Scraping Tweets

# %% [markdown]
# The programming language Python comes pre-installed with a large number of packages and modules that allow you to efficiently manipulate all kinds of data. However, the standard library of Python does not contain a package to work with Twitter data. Fortunately, the third-party package [Tweepy](http://docs.tweepy.org/en/v3.5.0/) provides all the necessary tools we need. In order use that package, we first need to install it. This can be done by executing the following cell:

# %%
# !pip install tweepy
# Out:
# Collecting tweepy
#   Downloading https://files.pythonhosted.org/packages/05/f1/2e8c7b202dd04117a378ac0c55cc7dafa80280ebd7f692f1fa8f27fd6288/tweepy-3.6.0-py2.py3-none-any.whl
# Requirement already satisfied: six>=1.10.0 in /anaconda3/lib/python3.6/site-packages (from tweepy) (1.11.0)
# Collecting requests-oauthlib>=0.7.0 (from tweepy)
#   Downloading https://files.pythonhosted.org/packages/94/e7/c250d122992e1561690d9c0f7856dadb79d61fd4bdd0e598087dce607f6c/requests_oauthlib-1.0.0-py2.py3-none-any.whl
# Requirement already satisfied: PySocks>=1.5.7 in /anaconda3/lib/python3.6/site-packages (from tweepy) (1.6.7)
# Requirement already satisfied: requests>=2.11.1 in /anaconda3/lib/python3.6/site-packages (from tweepy) (2.18.4)
# Collecting oauthlib>=0.6.2 (from requests-oauthlib>=0.7.0->tweepy)
#   Downloading https://files.pythonhosted.org/packages/e6/d1/ddd9cfea3e736399b97ded5c2dd62d1322adef4a72d816f1ed1049d6a179/oauthlib-2.1.0-py2.py3-none-any.whl (121kB)
#     100% |████████████████████████████████| 122kB 5.1MB/s ta 0:00:01
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.6/site-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /anaconda3/lib/python3.6/site-packages (from requests>=2.11.1->tweepy) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /anaconda3/lib/python3.6/site-packages (from requests>=2.11.1->tweepy) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.6/site-packages (from requests>=2.11.1->tweepy) (2018.1.18)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-2.1.0 requests-oauthlib-1.0.0 tweepy-3.6.0

# %% [markdown]
# In order to authorize our application to access Twitter through our account, we first need to make Python aware of our authentication codes. The folder of this workshop (which you saved on your Desktop, or somewhere else) contains a file named `config.py`. Open that file using the Sublime Text editor. You should see something similar to:

# %% [markdown]
# ![](images/sublime-config-file.png)

# %% [markdown]
# Update all variables with the appropriate values from your own scraping application (visit [https://apps.twitter.com/](https://apps.twitter.com/), copy your tokens and keys and paste them in the `config.py` file). After you have updated all variables, do not forget to **save** the file! To make Python aware of our configuration, execute the following code block:

# %%
import config

# %% [markdown]
# With the following code block, we set up all necessary components to access Twitter's API. We will first execute the cell and then try to understand, line by line, what all lines attempt to accomplish.

# %%
import tweepy

authentication = tweepy.OAuthHandler(config.consumer_key, config.consumer_secret)
authentication.set_access_token(config.access_token, config.access_secret)

api = tweepy.API(authentication)

# %% [markdown]
# The first line of this code block imports the `tweepy` package. This allows us to employ all functionality available in tweepy. The second line initializes a variable called `authentication`. We assign to that variable the value `tweepy.OAuthHandler(config.consumer_key, config.consumer_secret)`, which is an object available in tweepy handling the authentication for us. Note that this object takes two arguments (`config.consumer_key` and `config.consumer_secret`), which refer to the consumer key and consumer secret we set in our `config.py` file. The third line sets the access token of the authentication object. Again, as you can see, we make use of the information stores in our `config.py` file. Finally, at the last line, we initialize a variable called `api` and assign to it the object `tweepy.API(authentication)`, which takes a single argument (i.e. `authentication`).

# %% [markdown]
# It is well conceivable that this code block is a little overwhelming, but you don't need to understand all parts. It is, however, important that you at least try to read the lines and get a general impression of what is happening.

# %% [markdown]
# The good news is that this is basically all we need to do in order to access Twitter's API. For example, we can now use the variable `api` to access our own timeline on Twitter. Execute the following cell:

# %%
for tweet in tweepy.Cursor(api.home_timeline).items(10):
    print(tweet.text)

# %% [markdown]
# In the code block above, we make use of a so-called `for`-loop. A for-loop is one of the most important concepts in programming as it allows us to perform particular actions for multiple iterations. In this example, we loop over the first 10 items in our `api.home_timeline` and print the text of each tweet using `print(tweet.text)`. Try updating the number 10 with a different number and rerun the cell.

# %% [markdown]
# Let's have a look at another example of how to access your twitter account through the API. Using the following lines of code, we can print a list of all our followers:

# %%
for follower in tweepy.Cursor(api.friends).items():
    print(follower.name)

# %% [markdown]
# Finally, let's print a list of our 10 latest tweets:

# %%
for tweet in tweepy.Cursor(api.user_timeline).items(10):
    print(tweet.text)

# %% [markdown]
# Programmatically extracting our list of followers or our list of tweets is fun, but not particularly interesting. Let us now turn to our main application with which we can "keep the connection open" and gather all upcoming tweets about a particular topic, event or person. To this end, we need to make use of yet another functionality of tweepy, which is the `StreamListener`. The following code block gathers all new tweets that contain the word *python*. Execute this cell and wait for a couple of minutes. After that, press the "stop" button in your notebook (the black square).

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener

class TwitterListener(StreamListener):

    def on_status(self, status):
        print(status.text)

    def on_error(self, status_code):
        if status_code == 420:
            #returning False in on_data disconnects the stream
            return False

twitter_stream = Stream(authentication, TwitterListener())
twitter_stream.filter(track=['python'])
# Out:
# How to pack serverless Python actions - IBM Cloud Blog #IBM https://t.co/Mkg6adKWM9 https://t.co/Eeh7Mct62E
# Gênios 😂
# Saudade de ver @montypython https://t.co/oFcjYrgD88
# Python: Web Development and Penetration Testing
#
# ☞ https://t.co/YsVTWxNUkg
#
# #python #WebDevelopment https://t.co/RJoOPXYorH
# Introduction to programing Using Python #homework https://t.co/HYr5DPfAJ4
# #Monitoring #Tools | Python Logging https://t.co/Gbm4rj4HgL
# RT @opensourceway: How to create a 2D game with #Python and the Arcade library: https://t.co/tq3Oeh0u9b #PyCon https://t.co/gfTV6XXv24
# RT @hasdid: #Monitoring #Tools | Python Logging https://t.co/Gbm4rj4HgL
# RT @andartolo: As pessoas de bem da Noruega pediram que o filme "A Vida de Brian" fosse banido do país, e o governo baniu.
# Então, o Monty P…
# RT @yvNSHhtHVBRK7j5: python勉強中に「あれッ？低水準言語の方がよくね？」
# ｃ++勉強中に「あれッ？言語よりアルゴリズムじゃね？」
# アルゴリズム勉強中に「あれッ？数学も必要じゃね？」←今ココ
# Actually I have interests in multiple fields: #bigfour #consulting #investmentbanking and my personal education bac… https://t.co/6sP033hUGP
# RT @3v9758225471: #देशकादुश्मन_IG_अनिलराव
# #खूनी_सरकार #qanon
# A responsible police officer  mishandled barwala case and make Python of rope…
# RT @KainosCodeCamp: Another great breakout session from @SquinnieThePooh - “Introduction to Python” - Students learning so much from scratc…
# RT @andartolo: As pessoas de bem da Noruega pediram que o filme "A Vida de Brian" fosse banido do país, e o governo baniu.
# Então, o Monty P…
# Python: Web Development and Penetration Testing
#
# ☞ https://t.co/yMmr8S9Dte
#
# #python #WebDevelopment https://t.co/ufF7bWqXcY
# el marginal https://t.co/GfUVxR4KTy
# RT @vboykis: “All happy data scientists are alike; each unhappy data scientist uses a different Python plotting library.” - Anna Karenina
# RT @gp_pulipaka: Serving #DeepLearning Models with #TensorFlow-Serving’s #RESTful #APIs. #BigData #Analytics #MachineLearning #DataScience…
# RT @gp_pulipaka: Ncrack: A High-Speed Network Cracking Tool. #BigData #Analytics #NoSQL #Redis #PostgreSQL #MongoDB #Networks #DataScience…
# @3_dw1n @a_berut Sinon le package lmfit de python fait tout cela très bien...
# La serie de luismi https://t.co/rMEA3TxVZ0
# RT @mikedelgado: Comparison of top #datascience libraries for #Python, #R and #Scala.
# #coding #bigdata #AI #cloud #MachineLearning #Tech #d…
# Raspberry Pi...Python...Twitter...Bot...test
# RT @hungair0925: Day32 #100DaysOfCode
# -記事の削除機能に確認のモーダル設置!確認文がくどいなw
# -フォント周りももう一度立ち上げたら指定してたフォントになってた^^
# #Python #Flask https://t.co/sfljH86EnJ
# This Hours Photo: #weather #minnesota #photo #raspberrypi #python https://t.co/eEp5HlISZh
# RT @JorgeGarciaGom: See How To build a Countdown Timer with React!
#
# #programming #programmer #developer #coding #codeliving #nodejs #angula…
# RT @gp_pulipaka: Ncrack: A High-Speed Network Cracking Tool. #BigData #Analytics #NoSQL #Redis #PostgreSQL #MongoDB #Networks #DataScience…
# 1/2: We are working with a #tech #startup who is using the power of technology combined with applied nutritional sc… https://t.co/fZl14UXa4i
# RT @BlackHatEvents: Details of a new exploit technique that can take advantage of 0-days in common frameworks written in Python, Ruby, Java…
# https://t.co/UmfEGfevml #Python Python boss Guido van Rossum steps down after 30 years - The INQUIRER https://t.co/XSpeN5kFVU
# Leer un LIBRO https://t.co/RdKuTUhl9B
# Python: Web Development and Penetration Testing
#
# ☞ https://t.co/HNBoYwCrmt
#
# #python #WebDevelopment https://t.co/YGUynPoPmv
# RT @ProgrammerBooks: Easy SQL ...
#
#  https://t.co/mo8tuD1lfd
#
# #python #javascript #angular #angularjs #reactjs #vuejs #webdev #perl #ruby #C…
# 自社のイノベーションセンターにて人工知能研究室を立ち上げ活動開始。この国ではまだPython技術者が少ないので、まずはPythonを指導する事からはじめている。人工知能は下地ができてきたら妄想？を始めていく。
# New #job: Software Test Engineer / QA Engineer - BS1 - Python or JS Location: Bristol Salary: £30kpa - £50kpa ..… https://t.co/G4KuLTOHei
# RT @python_devv: Python: Web Development and Penetration Testing
#
# ☞ https://t.co/YsVTWxNUkg
#
# #python #WebDevelopment https://t.co/RJoOPXYorH
# Cool website for referencing Python syntax. Also includes examples for Sqlalchemy and testing. https://t.co/lia63NNPRg
# RT @pycoders: Using Gitlab pipelines to deploy Python packages in production and staging environments – https://t.co/t7FOyJe5UQ
# RT @ExperianDataLab: The #DataTalk podcast just launched on #iTunes.
# Subscribe &gt;&gt; https://t.co/YZ3uSHE3R1
# Topics: #DataScience #AI #Machin…
# @LaCraftyP Monty Python - SPAM https://t.co/XqG5a9ji7b via @YouTube
# D5 - #100DaysOfCode Continuing today with  #Python syntax: multi-line strings. Good explanation within this… https://t.co/HdRhRj1pOo
# RT @MrFresh: D5 - #100DaysOfCode Continuing today with  #Python syntax: multi-line strings. Good explanation within this #Codecademy tutori…
# @gwizcypz Haha I was talking bout the beer but the one eye python don’t see shades 😂
# El locro😫
# RT @CodingFlux_: Learning Penetration Testing With Python  https://t.co/iLapqV00Ce #Python #programming @CodingFlux_
# RT @schwa: Found a great using for Swift 4.2’s @dynamicMemberLookup doing Python “records” (ala @kennethreitz ) style sqlite binding: https…
# RT @betolink: At this point the Anaconda + #gdal stack is creating more problems than solutions. #python #gis
# RT @gp_pulipaka: Serving #DeepLearning Models with #TensorFlow-Serving’s #RESTful #APIs. #BigData #Analytics #MachineLearning #DataScience…
# Bht kharcha kerwa dia hay Hidayat and Mahmood Durrani mera, chopper machine, python and Hyenas mangwana parengy achi nasal k!!
# RT @realpython: 🐍📰 Itertools in Python 3, By Example https://t.co/pPOZjHhz6v
# RT @realpython: 🐍📰 Itertools in Python 3, By Example https://t.co/pPOZjHhz6v
# RT @KitPloit: Webkiller - Tool Information Gathering Write By Python. https://t.co/lJY78aE01I #Gathering #HoneyPot #Information #Informatio…
# @suzakulab かれこれロボットしかやってこなかったもので,pythonもjavascriptも１回触った程度なんですが,そんな私でも良ければ応募したいです.勿論勉強はします.
# どこから応募したら良いのでしょうか？
# RT @PythonHub: Haps – Configless Dependency Injection for Python https://t.co/KwcvWEaMVB
# ALRIGHT ALRIGHT ALRIGHT!😎😎
# Monty Python on #TwitterTips 🙌 https://t.co/h39zElfgp7
# hathaway nude black naked model happy birthday nude girl hottest teen age sex pussy ass tube monty python  https://t.co/c40CsFNw1o
# RT @PythonMist: Ibombshell - Dynamic Remote Shell https://t.co/7u6AtImcBm #Ibombshell #Listener #Pentesting #PowerShell #Python #Remote #SS…
# RT @pycoders: Understanding Python Dataclasses — Part 1 – https://t.co/4gBBXtlbfe
# Francella. https://t.co/gXRqKy1qC5
# RT @cht_partime: Desarrollador Python / Ruby https://t.co/jTfRPaCsFN #PartTime #chiletrabajos
# Maison Margiela 11 "Replica"  Women's Silver Green Python Skin Clutch https://t.co/cUS5stto70
# RT @securityaffairs: Code hosting service #GitHub can now  scan also for vulnerable #Python code
#
# #securityaffairs #hacking https://t.co/cy…
# RT @solamour: I've started an "Annotated #Python in @DynamoBIM" resource on @github
# https://t.co/yhz7gIKUST - Come download, fork or contri…
# RT @Ronald_vanLoon: 12 #Python Resources for #DataScience
# by @granvilleDSC @DataScienceCtrl |
#
# Read more here: https://t.co/MxaXSUXaBo
#
# #M…
# RT @TensorFlow: Graph models allow for all kinds of optimization, but it can be tricky to move between Python and graph code. To help with…
# On my list to read 📙 "Practical Web Scraping for Data Science: Best Practices and Examples with Python" by… https://t.co/vgng5Um5D2
# # pip install PySide2
#
# https://t.co/NpGJTnNt9m
# New startup idea: take Skype, exploit virtual reality &amp; the Internet of Things, and rewrite it in Python.
# 最近は面白そうな本はみなpythonだね -- アディティア・Y・バーガバ の なっとく! アルゴリズム を Amazon でチェック！ https://t.co/V9I128ubbH AmazonJPさんから
# You could never make eye contact
# Everything you got was based off of my contacts
# You a fraud, but I'm a remain icon… https://t.co/A0kTDyh8KQ
# @pashulman To be fair, Monty Python could come up with a better skit.
# RT @Camila_Angeloni: el marginal https://t.co/GfUVxR4KTy
# Fresh from @KDNuggets: 5 Quick and Easy Data Visualizations in Python with Code https://t.co/hVcCIaVvqC
# @geor97 @Davidmetroland @SybilleRompe @asknbid @AwayFromTheKeys @Vikingavfc @Macid3000 @IrishEurophile… https://t.co/P4fqAm5JBL
# RT @PythonWeekly: A Basic Pandas Dataframe Tutorial for Beginners  https://t.co/KvZKVWfL4d #python #pandas https://t.co/CdTeSIAmf6
# Today is an implementation day.  Taking full advantage of these two resources and implementing greatness:… https://t.co/dh12pxCb3R
# @_Reinose ㄴㄴㄴㄴ 그 코드는 task가 하나라 전혀 상관 없고 async한 task가 두개 이상 있을때 효과가 있는데 자세한건 https://t.co/Wd4clFGv5f 여기 보면 될듯
# 그냥 평상시에 사용하는 방법으로는 차이 없음
# RT @gboeing: I did a comparison of city street network orientations in major US cities, and now I've got a better sense of why I find Bosto…
# @nicolebyer Do they.. know Monty Python isnt one person?
# Python: Web Development and Penetration Testing
#
# ☞ https://t.co/ySnYbrlXrS
#
# #python #WebDevelopment https://t.co/zKxT9llnmi
# En un tiempo en el que todo cambia todos los días, ganan enteros los lenguajes dinámicos como #python o… https://t.co/hRlqsFfyUJ
# @Crell @mwop Comprehensions as in list comprehensions like Python has? I &lt;3 those.
# EuroPython 2018: Find a new job at the conference
# https://t.co/n5VdHxKBBL
# +1 WebbyBot #Python
# IM FUCKING DONE WITH YOU 😂😂😂😂😂😂😂😂😂😂
# @BernardoMF @FinancialTimes É por isso que o Monty Python se aposentou, foram superados lá em ironia e no nosso congresso no non sense.
# Django 2.1 release candidate 1 released | Weblog | Django
# https://t.co/ku6jGuAlVq
# +1 WebbyBot #Python
# The Happy Medium: Distinguished Service Award Winner Tim Peters
# https://t.co/1khgAlKTZm
# +1 WebbyBot #Python
# DevOps Team Lead: PriceMetrix Inc. (Toronto ON): "Studio/NAnt/ Python/ Ansible/Chef/Puppet. Experience in Microsoft… https://t.co/Qai89WayqR
# RT @yvNSHhtHVBRK7j5: python勉強中に「あれッ？低水準言語の方がよくね？」
# ｃ++勉強中に「あれッ？言語よりアルゴリズムじゃね？」
# アルゴリズム勉強中に「あれッ？数学も必要じゃね？」←今ココ
# RT @RichardNewby3: As TM caves in time and again to her #Brexit extremists, she increasingly resembles the black knight in Monty  Python an…
# RT @RageKingg: requisitos: conhecimento avançado em c++, c#, Java, python, php, javascript, html, css.
# inglês avançado (obrigatório) com ce…
# RT @opensourceway: How to create a 2D game with #Python and the Arcade library: https://t.co/tq3Oeh0u9b #PyCon https://t.co/gfTV6XXv24
# So I could make decision clearly on which field I should all-in. I care abt the cost of time..but think deeper, is… https://t.co/xNZMPZBIdm
# RT @Boostlog_js: Integrate Google Maps in a Website using JavaScript
# https://t.co/3CdOCtaR11
#
# #Developer #node #nodejs #coding #js #reactjs…
# RT @Peerlyst: Rich Hoggan teaches #python for #pentesters https://t.co/5Qz2miy3dg
# Tardis 1.0.0 released. https://t.co/CI2pBtBerp #python #backup #encryption #versioning https://t.co/DuK9rMgxqK
# LiveDataFrame – Quickly Prototype Trading Strategies in Python. https://t.co/xn9ywWertF
# 2/2: They are well funded and ready to take the team to the next level:
# Backend SOFTWARE ENGINEER -… https://t.co/wuxmgj47pG
# Si comienzas con #Python y en #machinelearning mejor que tengas las herramientas adecuadas! Leer: Instala tu ambien… https://t.co/kiPYZzQa1C
# RT @ziyaetuk: Is this true...🤣
# #javascript #typescript #react #react #vuejs #webdevelopment #webdeveloper #angular #webdesigner #html #html…
# RT @Boostlog_js: Integrate Google Maps in a Website using JavaScript
# https://t.co/3CdOCtaR11
#
# #Developer #node #nodejs #coding #js #reactjs…
# RT @tecnoloxia: Dicionario Scratch-Python no Proxecto Algoritmia https://t.co/36CrulMmPw https://t.co/yEAkdB64qo
# @Andarne_ you could definitely write some python script to capture images at an interval and then have the pi uploa… https://t.co/J2Q5VFF4Cy
# RT @python_devv: Bayesian Optimization in Python with Hyperopt
#
# ☞ https://t.co/oB3WJd7ADX
#
# #python #Hyperopt https://t.co/jekUDBd1OP
# Python Software Foundation: The Happy Medium: Distinguished Service Award Winner Tim Peters https://t.co/7WINJ1JvnN
# Real Python: Lists and Tuples in Python https://t.co/L9T9Va66EI
# Not too long until the @chicagopython tomorrow at Braintree. Come learn about #Python Project Night - Pytest: https://t.co/wYjh1Vri6V
# Five-feet long python rescued from house in Gurgaon https://t.co/46xwZKsrOc https://t.co/v6yXUXorKr
# Did I just describe to someone the Labour Party's internecine squabbles as the hydrocephalic lurvechild of Monty Py… https://t.co/sx2zp9Ha7Z
# RT @kdnuggets: Basic #Image #DataAnalysis Using #Numpy and #OpenCV, Part 2 #Python #DataScience #DataVisualization https://t.co/s66Md6Jxty…
# RT @gp_pulipaka: Serving #DeepLearning Models with #TensorFlow-Serving’s #RESTful #APIs. #BigData #Analytics #MachineLearning #DataScience…
# @Mega_NO @mchris4duke Iguanas are the Squamata Pirates. Here we can see a depiction of an R user's first day in a f… https://t.co/sLye02SHT8
# @beaglebets @soniagupta504 As a Python dev that occasionally wears sport coats with elbow pads I feel personally attacked
# RT @MattGeeSymonds: @geor97 @Davidmetroland @SybilleRompe @asknbid @AwayFromTheKeys @Vikingavfc @Macid3000 @IrishEurophile @CharlieHicks90…
# @CadenHouse I've just applied for the position.
#
# Why? Why not?
#
# I've actually enjoyed playing the Borderlands game… https://t.co/W9SqCDuO3Q
# RT @Reza_Zadeh: AutoGraph generates TensorFlow graphs from arbitrary Python, supporting control flow such as while loops, if statements, br…
# RT @gp_pulipaka: Ncrack: A High-Speed Network Cracking Tool. #BigData #Analytics #NoSQL #Redis #PostgreSQL #MongoDB #Networks #DataScience…
# 10 Basic Python Examples That Will Help You Learn Fast https://t.co/P8vDYJRgsv #MakeUseOf
# RT @LBF_LaBonneFee: « J’en ai pleuré : l’idée que… six hommes blancs d’Oxford ne puissent plus faire un spectacle comique. À présent il nou…
# naked monty python sex knocked out sex woman mature nude fat girls naked eading винкс секс downey adult  https://t.co/DdpQvaZLr9
# RT @thelynchpinau: Day 87: #100DaysOfCode progress: today I worked on Fullstack web apps made easy / D3 (more coding) https://t.co/qyK0C1P0…
# A simple neural network with #Python and Keras https://t.co/cOlCNdz00F
# Python: Web Development and Penetration Testing
#
# ☞ https://t.co/0Ix3uwDH1g
#
# #python #WebDevelopment https://t.co/uoBQ35ydJR
# RT @Boostlog_js: Integrate Google Maps in a Website using JavaScript
# https://t.co/3CdOCtaR11
#
# #Developer #node #nodejs #coding #js #reactjs…
# RT @wbohon: Yes!! And for those of us who don’t have grad students to teach us Python there’s this excellent @IRIS_EPO webinar by @GeoGinge…
# RT @ziyaetuk: Is this true...🤣
# #javascript #typescript #react #react #vuejs #webdevelopment #webdeveloper #angular #webdesigner #html #html…
# Le Monty Python Terry Gilliam raille la diversité à l’écran : “Je suis une lesbienne noire en transition”… https://t.co/9InJvIVDQq
# RT @andartolo: As pessoas de bem da Noruega pediram que o filme "A Vida de Brian" fosse banido do país, e o governo baniu.
# Então, o Monty P…
# RT @MannyCodesCA: Day 26/100 of the #100DaysofCode challenge! I’m trying to install the pip package manager for Python on my Mac but is ask…
# RT @kaggle: We heard you loud and clear! We just released a new Python course based on our popular 7-day Learn Python Challenge. Our goal:…
# RT @Boostlog_js: Integrate Google Maps in a Website using JavaScript
# https://t.co/3CdOCtaR11
#
# #Developer #node #nodejs #coding #js #reactjs…
# RT @jcldf: A simple python script that generates random HTTP/DNS traffic noise in the background while you go about your regular web browsi…
# RT @sonorityscape: https://t.co/bRrw6EPBLv #gameaudio #sounddesign #gamedev In the past year I've spent quite some time applying for variou…
# RT @thelynchpinau: Day 87: #100DaysOfCode progress: today I worked on Fullstack web apps made easy / D3 (more coding) https://t.co/qyK0C1P0…
# Thank you @ThinkITprocure. If any school wishes to learn about this work please contact us.  We are happy to talk a… https://t.co/8slRsXeCPV
# RT @ndtv: Five-feet long python rescued from house in Gurgaon https://t.co/46xwZKsrOc https://t.co/v6yXUXorKr
# Lists &amp; Tuples in #Python
# by John Sturtz via @realpython
# https://t.co/oQkl1mhkew
# RT @torinellis: Need #backend engineers
#
# to continue shaping this membership platform for artistic, content, and vocal creatives.  #sanfra…
# 3 Days of Awesome #IBMi Education starts tomorrow at #OCEANTechCon18! #SQL #Watson #PHP #Python #APIs #Nodejs #RPG… https://t.co/BHiyIpI5G8
# RT @pycoders: Using Gitlab pipelines to deploy Python packages in production and staging environments – https://t.co/t7FOyJe5UQ
# RT @marcusborba: How to Think About #AI and #MachineLearning Technologies, and Their Roles in Automation
#
# #BigData #DeepLearning #DataScie…
# RT @geeksam: I occasionally see posts about #nbpy and my first thought is always “there’s a python org for non-binary folks? THAT IS SO COO…
# RT @camhouser: New geopandas! https://t.co/8kC2hTmNiz
# Olha aí, que interessante.... https://t.co/WnJCh10SDu
# RT @armaninspace: A simple neural network with #Python and Keras https://t.co/cOlCNdz00F
# “Evolution of a salesman: A complete genetic algorithm tutorial for Python” by @ezstoltz https://t.co/MORAb0aAzF
# Phew, with 5 mins to spare, managed to quickly update the Episode 75 Python's World download to 1.13 in time for th… https://t.co/B4WNwZyPbd
# ADULTDEEPFAKESCOM Miley Cyrus Deep Fake (Double Hand Job)
#  https://t.co/ux81qjQNch
#  kamapichachi in xxx sex videos… https://t.co/MUGkDSCgfk
# El asado y el mate https://t.co/3xATxay3Ya
# Looking for a new career? Learn Python. #machinelearning https://t.co/eFz4syt3vJ https://t.co/8CTgjrqeTV
# RT @opensourceway: How a #Python-based tool built by three @Netflix engineers decreased outage response time from 45 minutes to just 7: htt…
# Show HN: LiveDataFrame – Quickly Prototype Trading Strategies in Python https://t.co/FvuPYYqT6p
# https://t.co/4Uohl71FBp #Python Start Building Python Apps with These 9 Courses - XDA Developers (blog) https://t.co/oWInyUboMh
# RT @SAA_ERS: Alejandra Dean of the Massachusetts Archives @SecretaryOfMass kicks off  our “Script It!” Series! Learn how she used Python to…
# RT @CarlaaRinga: la faraona https://t.co/5ANCmt8UCZ
# Gostei de um vídeo @YouTube https://t.co/ROBXtm0AQl Python #07 - Operadores Aritméticos
# RT @mvolpe: This is a really in depth look at "Python Paul's" recruiting process and how I joined https://t.co/OCLVUHn2q2 as CEO.
#
# https:/…
# I love Python but I gotta be honest... I really miss the ++ operator
# RT @AustraliaZoo: Happy #WorldSnakeDay🐍 Here is a gorgeous spotted python on the Steve Irwin Wildlife Reserve in Cape York Peninsula! The S…
# RT @DiobuZone_PH: #BuhariInHague! Arrest Him Now! Evil Man Goes To Netherland 🇳🇱, The Home Of ICC @IntlCrimCourt
# Pres Jubril Buhari Is In H…
# RMBridgeは諦めてpython-broadlinkでRMMiniを制御しようと思うんだけどうまくRMMiniを掴んでくれない
# なんで https://t.co/UJ521hMSHR
# RT @TensorFlow: Graph models allow for all kinds of optimization, but it can be tricky to move between Python and graph code. To help with…
# The Naive Bayes Algorithm in Python with Scikit-Learn https://t.co/NGlizghu75
# RT @python_tip: You most likely know about 'global' and 'local' variables but do you know 'nonlocal'?
#
# https://t.co/rmQjUgUKfZ
# https://t.co…
# #Highlands Play Monty Python #Spamalot Scratchcrad at William Hill with £150 Bonus https://t.co/rkgEQgyoTf
# RT @PyDataCba: ¡Quedan dos semanas para mandar propuestas de charlas y tutoriales! #datascience #python #Analytics #dataviz #MachineLearnin…
# RT @AnalyticsVidhya: Understanding Ensemble modeling will get much easier with this tutorial by Aishwarya Singh. She has comprehensively ex…
# RT @kdnuggets: Helpful Python Code Snippets for Data Exploration in Pandas https://t.co/d1y54QtgrA https://t.co/nCTtR3ofQs
# RT @PyDataCba: Only two weeks left to send us your proposals of talks and tutorials! #datascience #python #Analytics #dataviz #MachineLearn…
# RT @gp_pulipaka: Big Data and Container Orchestration with Kubernetes (K8s). #BigData #Analytics #MachineLearning #DataScience #AI #Python…
# See you all there on Friday.
# Going to be 😎 hanging out with everyone.
# Housemates rescued as well 😅 https://t.co/7romHkrTuH
# RT @TensorFlow: Graph models allow for all kinds of optimization, but it can be tricky to move between Python and graph code. To help with…
# Dormir siesta. https://t.co/Rpclfz1mWU
# python里缩进应该用tab还是空格呢！
# RT @MAZIOBIBOND1: https://t.co/AQS4iG3bpY
# The Helsinki Summit -- a cross between Tom Clancy and Monty Python. My latest in Newsweek.
#
# https://t.co/iarnxao2CR
# Python、たごとよっぴーがモデレーター（一番厄介なやつ）になってることを確認した
# @TheCryptoDog This is entirely possibly. Ocaml and Python might be a good candidate too. I mean there are less quir… https://t.co/si4s9nXUgZ
# Offre d'emploi en #CDI #Toulouse Développeur Python https://t.co/3aPjNG2zCx
# Better than the giant dead parrot for Monty Python, or no?
# @TheCryptoDog This is entirely possible. Ocaml and Python might be a good candidate too. I mean there are less quir… https://t.co/HHzMN9KUrN
# Python Pizza sta tornando! 🍕 #Python https://t.co/kquHHFOpIp
# RT @nnja: ⚡️I'm hosting a women's &amp; non-binary community breakfast at #EuroPython2018 in Edinburgh with @naomiceder, @saradodd3 and Suzanne…
# RT @iamtrask: Man - just found out about Python's "traceback" library. It lets you print the stack trace at any location.
#
# Not sure what p…
# RT @sour_bones: Specialised Instructors Wanted:
# Front-end Web Development, Back-end Web Development (PHP, Python and MySQL) and C# Programm…
# RT @djangocon: There are still a few tickets available at early bird prices! Come  and join us. https://t.co/dRLNIrxdkn https://t.co/DCUEpu…
# I like how they say 'the python was rescued' and not the Gurgaon family in the house https://t.co/lia1IrbkCo
# @BrexitIsToxic That’s right! I’ve got a couple of Masters degrees and I loved it.
#
# It was the funniest thing on TV since Monty Python.
# Exactly. Knowledge exchange + sharing a learning experience. https://t.co/V9ZDDSlYm8
# @ralsina @elfsternberg @StabbyCutyou @raudelmil That’s the real reason people don’t want to switch to Python 3: ins… https://t.co/LDLj84aSZl
# On my way to NYC for #HOPE ! Gonna give a workshop on building your own led array (with a pi and python).  Got just… https://t.co/Jx2eq9iqYs
# RT @Boostlog_js: Integrate Google Maps in a Website using JavaScript
# https://t.co/3CdOCtaR11
#
# #Developer #node #nodejs #coding #js #reactjs…
# RT @gp_pulipaka: Ncrack: A High-Speed Network Cracking Tool. #BigData #Analytics #NoSQL #Redis #PostgreSQL #MongoDB #Networks #DataScience…
# gusto  ko maglabas ng feels dun sa group, kaso baka may maspoil sa PND huhu ateee @serialsleeperwp helppppppppppp m… https://t.co/IWC2Sdpj88
# Consulte CNPJs na Receita em python e sem captcha https://t.co/D4vtv1V3wV
# RT @ziyaetuk: Is this true...🤣
# #javascript #typescript #react #react #vuejs #webdevelopment #webdeveloper #angular #webdesigner #html #html…
# alright science twitter and/or geek twitter, i have a question for you:
#
# how do you go about converting huge (1GB+)… https://t.co/ZrOqEpz3py
# normally i just do the lazy thing and use excel to do my dirty work for me, but these datasets are too big for that… https://t.co/zuBMYzHEAr
# RT @_KenReid: @MichelleRempel This Liberal gvt would be excellent fodder for the Monty Python troupe! So much incompetence simply fosters m…
# Automate the Boring Stuff with Python: Practical Programming for Total Beginners  https://t.co/uHeEQ5TzPQ
# RT @kdnuggets: Basic #Image #DataAnalysis Using #Numpy and #OpenCV, Part 2 #Python #DataScience #DataVisualization https://t.co/s66Md6Jxty…
# I can't help but picture some of the administrators/communications folk at this school as the "It's just a flesh wo… https://t.co/pgcKOM99A1
# nargin functionality (from Matlab) in Python? - /u/amtorrest https://t.co/4jGwVMedFv
# Heroes of the Storm でリプレイファイルからドラフトの内容を表示するツールです。 Python, Git のインストールが必要です。詳しくはパッケージ内の README を御覧ください。あと、何か問題があればお知… https://t.co/fdaH6TqhON
# RT @Camila_Angeloni: el marginal https://t.co/GfUVxR4KTy
# RT @Avaltenea: Cuando en @lasdesistemas deciamos que trabajamos para potenciarnos no había caido en la dimensión del asunto hasta que en un…
# Docstrings are used to comment out large amounts of code to turn it off, but also very importantly used in a specif… https://t.co/3Q9MFAwqLR
# @SteveSGoddard Incredible , completely beyond the pale! I see his feed continues to make the accusation. U would ha… https://t.co/bhEkAfthyP
# RT @pycoders: Using Gitlab pipelines to deploy Python packages in production and staging environments – https://t.co/t7FOyJe5UQ
# RT @abuchi_2: #BuhariInHague! Arrest Him Now! Evil Man Goes To Netherland 🇳🇱, The Home Of ICC @IntlCrimCourt
# Pres Jubril Buhari Is In Hague…
# RT @DiobuZone_PH: #BuhariInHague! Arrest Him Now! Evil Man Goes To Netherland 🇳🇱, The Home Of ICC @IntlCrimCourt
# Pres Jubril Buhari Is In H…
# RT @DesignHiero: --&gt;#Design #GraphicDesign #GlitchArt #DesignQuote #IterativeDesigner #BotArt #Python #Fractals https://t.co/KVdP4xyDh5
# Temperatura atual da CPU, 46 Cº #Automation #Python #RaspberryPi
# Desarrollador Backend/CTO at BartyApp @Barty_app
# #django #python #mongodb
# https://t.co/BY1pbPGWNY
# [P] TinyGBT: A Tiny, Pure Python implementation of Gradient Boosted Trees. https://t.co/ESB4Xbab07
# 2018-07-18 20:00 Python test
# #curiosityrover on #Mars. Can you guess what year it was taken? (SOL=371) - powered by #Python https://t.co/b6HmBaq5nQ
# Five-Feet Long Python Rescued From House In Gurgaon https://t.co/vZNPNTfEwj https://t.co/JnXSPjeNP9
# How many ways can you print 3 without using any numbers in #python? https://t.co/inohEMsf98
# D5: Yesterday, I worked with the #Python turtle module &amp; reviewed lists &amp; “for” loops to iterate the patterns. I re… https://t.co/YSPTfBDKCx
# RT @vivian_maxine: D5: Yesterday, I worked with the #Python turtle module &amp; reviewed lists &amp; “for” loops to iterate the patterns. I realize…
# RT @DoraDollarDora: Python、たごとよっぴーがモデレーター（一番厄介なやつ）になってることを確認した
# RT @ChannelNewsAsia: Yellow python spotted at HDB block in Queensway https://t.co/l4BheqD1jk https://t.co/HY22tawjok
# Python Application Development Using Flashtext
# https://t.co/PV55Bgpdtr
#
# #Developer #node #nodejs #coding #js… https://t.co/GpbQG8AyXt
# RT @BoostLog_Python: Python Application Development Using Flashtext
# https://t.co/PV55Bgpdtr
#
# #Developer #node #nodejs #coding #js #reactjs…
# ((That's horrible. I almost got bitten by a python at a carnival once.)) https://t.co/10tnzayeFQ
# RT @awiltsch: Excited to get this out there! https://t.co/5KzSWLxMPv
# Python's World - Giving you a tour of everything built in my world since the last tour! https://t.co/57qYBxSpYs
# RT @raymondh: #python tip:  prefer str.index() over str.find().
#
# The latter returns -1 for missing values.  Unfortunately, -1 is also a val…
# RT @kdnuggets: Basic #Image #DataAnalysis Using #Numpy and #OpenCV, Part 2 #Python #DataScience #DataVisualization https://t.co/s66Md6Jxty…
# #Python Send Email Example https://t.co/NvGJDOUUDZ
# C C++ #Python Engineer Computer Vision, #MachineLearning. - [ 📋 More Info  https://t.co/hAvFMHEUiO ]  #Python #jobs… https://t.co/z9jxcJ1cQo
# RT @nnja: ⚡️I'm hosting a women's &amp; non-binary community breakfast at #EuroPython2018 in Edinburgh with @naomiceder, @saradodd3 and Suzanne…
# pgn2gif - A small tool that generates 640x640 gif of chess pgn. https://t.co/WGzUCEKEr0 #python
# :: Oh sheet https://t.co/hxX3ejd6EH
# RT @BoostLog_Python: Python Application Development Using Flashtext
# https://t.co/PV55Bgpdtr
#
# #Developer #node #nodejs #coding #js #reactjs…
# RT @guilhermejd1: Consulte CNPJs na Receita em python e sem captcha https://t.co/D4vtv1V3wV
# @Twitch Hey, Twitch. Is it safe within the rules to livestream and watch Monty Python on Twitch? I’m curious.
# Har du en Mac-dator?
# 1. Öppna din terminal
# 2. skriv python
# 3. tryck enter
# Nu kan du testa programspråket python i… https://t.co/9xtrfwCXaL
# Bielsa https://t.co/mJoLV9NCGE
# Heroes of the Storm でリプレイファイルからドラフトの内容を表示するツールです。 Python, Git のインストールが必要です。詳しくはパッケージ内の README.txt を御覧ください。あと、何か問題があ… https://t.co/CMzb1lVyxe
# RT @pythonbytes: We cover the big news about Guido stepping down from decision-making in Python on the latest episode of @pythonbytes with…
# The only issue is ECDF plots are not as common so people (myself included) have difficulty interpreting them at fir… https://t.co/1LOxrZ50iI
# 次はPythonでもう一個上のサービスを一から作るぞ
# @lifttheveil411 @UNIRockTV @defangolives This specific graphic was created with https://t.co/Zc6fDFiqkE and a pytho… https://t.co/xG7oFsS3ey
# Comparison of Top 6 Python NLP Libraries https://t.co/03IouPqOCw #analytics
# Get started with blockchains and cryptocurrencies in Python. https://t.co/desl07DpZG
# RT @freeCodeCamp: Get started with blockchains and cryptocurrencies in Python. https://t.co/desl07DpZG
# ⭐️ Calculatrice Numworks : équations, saisie naturelle et transfert de scripts Python https://t.co/UVyspAoix5
# Pythonista culture is so totally fucked up.
# Look at this thread https://t.co/rNDiyVzWmi
# and how not a SINGLE perso… https://t.co/C9S11lDHU9
# @WebGo3 #codepen #wplife #Javascript #developer #java #php #instagood #i❤python #python #vscode #node #code… https://t.co/UBkigatTxl
# // A few years ago I went camping and walked right past a cottonmouth. https://t.co/itALEO5CFL
# With its Snowball Edge, AWS now lets you run EC2 on your factory floor https://t.co/kMIW0sOD0N #aws #python… https://t.co/jbqZoZZ1VI
# "Why is Python so slow?" https://t.co/sx7TEtzCGw #cybersecurity #infosec #code
# 【python】pytubeを使ってYouTubeからコンテンツをダウンロードする
# https://t.co/sL5EXU00Rd
# @WebGo3 #codepen #wplife #Javascript #developer #java #php #instagood #i❤python #python #vscode #node #code… https://t.co/FtgJnFTcSi
# RT @yvNSHhtHVBRK7j5: python勉強中に「あれッ？低水準言語の方がよくね？」
# ｃ++勉強中に「あれッ？言語よりアルゴリズムじゃね？」
# アルゴリズム勉強中に「あれッ？数学も必要じゃね？」←今ココ
# python3-indy 1.5.0-dev-627 https://t.co/DifpHItmc4
# RT @stvemillertime: A quick fun #APT28 blast from the past, here's some sample sourcecode of the "CHOPSTICK" aka "Xagent" proxy piece, whic…
# #Python #Programming #Language in Embedded #SoftwareDevelopment - Core Roles
# https://t.co/tFY69s01pe
# #MachineLearning #Nodejs #Apps
# RT @pycoders: Understanding Python Dataclasses — Part 1 – https://t.co/4gBBXtlbfe
# ¿Por qué #Python es tan lento? https://t.co/GolqdXYeIz
# @marcorubio @AmericaNewsroom We are going full “ Monty Python “ ... black knight episode now ... nice !!!
# RT @yvNSHhtHVBRK7j5: python勉強中に「あれッ？低水準言語の方がよくね？」
# ｃ++勉強中に「あれッ？言語よりアルゴリズムじゃね？」
# アルゴリズム勉強中に「あれッ？数学も必要じゃね？」←今ココ
# Python勉強しはじめた
# RT @yvNSHhtHVBRK7j5: python勉強中に「あれッ？低水準言語の方がよくね？」
# ｃ++勉強中に「あれッ？言語よりアルゴリズムじゃね？」
# アルゴリズム勉強中に「あれッ？数学も必要じゃね？」←今ココ
# Školení pro mírně pokročilé programátory v jazyce Python, kteří v tomto jazyce vyvíjejí (či plánují vyvíjet) softwa… https://t.co/FszKMM8DLj
# @SnakeDiscovery I want to get a ball python soon. Any tips on enclosure set ups and simple dos and don'ts of owning a ball python?
# RT @MLSummit_DE: 🔥 #MachineLearning &amp; #Python - bereit für die heißesten Themen der Entwickler-Welt? Jetzt am 2-in-1-Trainingsevent teilneh…
# This #job might be a great fit for you: Full Stack Python/PHP Web Developer (Contract) - https://t.co/28UV3wq1EN… https://t.co/frGIwooFN3
# RT @PythonWeekly: pgn2gif - A small tool that generates 640x640 gif of chess pgn. https://t.co/WGzUCEKEr0 #python
# RT @treyhunner: How can you make your own iterators in #Python? 🤔🐍
#
# I wrote an article on this:
# https://t.co/kDDXk30TAP
# RT @SwiftOnSecurity: Why did the alt-right fork all python libraries?
#
# They wanted to own the libs.
# RT @TechHeavenCZ: Školení pro mírně pokročilé programátory v jazyce Python, kteří v tomto jazyce vyvíjejí (či plánují vyvíjet) software.…
# RT @Amaka_Ekwo: IgboNative on Twitter https://t.co/NTnzoxBr6d
# RT @PythonWeekly: pgn2gif - A small tool that generates 640x640 gif of chess pgn. https://t.co/WGzUCEKEr0 #python
# RT @BakwasRadio: I like how they say 'the python was rescued' and not the Gurgaon family in the house https://t.co/lia1IrbkCo
# RT webcodegeeks: #Python Send Email Example https://t.co/MOdqhwFtQC
# RT @BakwasRadio: I like how they say 'the python was rescued' and not the Gurgaon family in the house https://t.co/lia1IrbkCo
# Los sanguches de miga , el queso rallado en los fideos , el baggio multifruta https://t.co/jL8W3AqgWF
# RT @IgboNative: 2019 Python dance will be for everybody, since we allowed our hate and tribalism blind us in kicking away the only democrac…
# RT @Amaka_Ekwo: IgboNative on Twitter https://t.co/NTnzoxBr6d
# @quixalicious, thanks for contributing to our official #smtpapi library! https://t.co/1cTc2X6Z68
# @emzoticofficial I want to get a ball python soon. Any tips on enclosure set ups and simple dos and don'ts of owning a ball python?
# RT @PythonGB: Python's World - Giving you a tour of everything built in my world since the last tour! https://t.co/57qYBxSpYs
# We're #hiring! Read about our latest #job opening here: Senior Python Developer - https://t.co/bRDEY4JLlk #IT #FortLauderdale, FL #CareerArc
# RT @IgboNative: 2019 Python dance will be for everybody, since we allowed our hate and tribalism blind us in kicking away the only democrac…
# RT @DesignSpark_JP: ラズパイのOSにはデフォルトでマインクラフトという有料ゲームがバンドルされています。「PI EDITION」というバージョンで、Pythonでプログラミングすることできます。
# https://t.co/UoyQZIOV5W https:/…
# Python's World Tour &amp; Download! (#3) | Python's World (Minecraft Survival Let's Play) | Episode 75 https://t.co/JEoggdaPaz @PythonGB
# CHOCOTORTA 😣 https://t.co/on3y8T83wE
# Check this out, Reef Technologies is hiring a Python Backend Developer to help with gpu Work Remotely! https://t.co/e3T4plriGn 🤔
# Who's going to the #MKE #Python meetup on Monday? Join us: https://t.co/RWXXgnYfHB
# RT @BakwasRadio: I like how they say 'the python was rescued' and not the Gurgaon family in the house https://t.co/lia1IrbkCo
# @gertchu_cowson @MatthewStadlen Matt is the son of a High Court Judge and went to St Pauls school. Yet somehow he w… https://t.co/xhgqxzdTna
# @JaafarTrull nice!
#
# maybe this be useful to you: small script to send Eigen/vector&lt;double&gt; from gdb to another pyth… https://t.co/AjcM6A7sNb
# RT @yvNSHhtHVBRK7j5: python勉強中に「あれッ？低水準言語の方がよくね？」
# ｃ++勉強中に「あれッ？言語よりアルゴリズムじゃね？」
# アルゴリズム勉強中に「あれッ？数学も必要じゃね？」←今ココ
# An older dude I work with greeted me today by saying "Hey asshole," and then proceeded to tell me he'd seen me on t… https://t.co/Rx50e1Q9xG
# ⭐️ Calculatrice Numworks : équations, saisie naturelle et transfert de scripts Python https://t.co/153KlkdmpG
# @JohnCleese You should still find it hilarious. Trump is no more a soviet agent than I am ( I am not by the way ) l… https://t.co/FpEHgAxapP
# RT @satofumi_: Heroes of the Storm でリプレイファイルからドラフトの内容を表示するツールです。 Python, Git のインストールが必要です。詳しくはパッケージ内の README.txt を御覧ください。あと、何か問題があればお知らせ下さい…
# 30 Free Courses: #NeuralNetworks, #MachineLearning, #Algorithms, #AI
# by @granvilledsc @geoff_hinton |
#
# Read more at… https://t.co/A0fJUhErhS
# RT @Ronald_vanLoon: 30 Free Courses: #NeuralNetworks, #MachineLearning, #Algorithms, #AI
# by @granvilledsc @geoff_hinton |
#
# Read more at htt…
# When learning Python/Django, should I set up a local server on my Mac or should I just use Google App Engine? by Hi… https://t.co/mhUvVTb9md
# RT @rajatmonga: A great way to combine @TensorFlow graphs and Python code. Start with eager execution, deploy with graphs. https://t.co/Nxb…
# #Day2
# 1. Tried a problem on GeeksforGeeks, almost solved some minor test case still pending.
# 2. Learned more about… https://t.co/JjGZztPjCH
# Las milanesas, el asado, las pastas y luego seguir ahre https://t.co/fbkpHOeBqi
# RT @ramanuj_5: #Day2
# 1. Tried a problem on GeeksforGeeks, almost solved some minor test case still pending.
# 2. Learned more about python un…
# Few of the geckos left in stock for stupid LOW price... DM for details 🐍🦎🐍 https://t.co/8rt0Guml1S… https://t.co/C83rGLKNmY
# RT @jrlarsen: 42% off everything at @ManningBooks until Jul 20
#
# Use code paywall42
#
# https://t.co/eSjbceqmuK
#
# #golang #swiftlang #csharp #py…
# A great introduction for anyone interested in starting #ML in #Python, and a useful reference for the rest of us. https://t.co/b2i5jr4NCc
# RT @yvNSHhtHVBRK7j5: python勉強中に「あれッ？低水準言語の方がよくね？」
# ｃ++勉強中に「あれッ？言語よりアルゴリズムじゃね？」
# アルゴリズム勉強中に「あれッ？数学も必要じゃね？」←今ココ
# RT @Ronald_vanLoon: 30 Free Courses: #NeuralNetworks, #MachineLearning, #Algorithms, #AI
# by @granvilledsc @geoff_hinton |
#
# Read more at htt…
# RT @johanarozano: La serie de luismi https://t.co/rMEA3TxVZ0
# Five-Feet Long Python Rescued From House In Gurgaon - Trending A to Z || https://t.co/ti6pWhv3nc || #Cities
# The latest The List of Python software Daily! https://t.co/0qUL5SwCM2 Thanks to @adri72 @Progrmlanguages @onemonthedu #programming #coding
# RT @tjowens: “Processing Metadata with Python: An “os.walk”through” for archivists https://t.co/QOIutLV468
# RT @gp_pulipaka: DataWave: A #BigData Ingest/Query #JavaScript Framework that leverages #ApacheAccumulo. #Analytics #Hadoop #MachineLearnin…
# RT @gp_pulipaka: Serving #DeepLearning Models with #TensorFlow-Serving’s #RESTful #APIs. #BigData #Analytics #MachineLearning #DataScience…
# Pyenv – Install Multiple Python Versions for Specific Project https://t.co/BSnc1dJ1Se https://t.co/7rXFddpPjg
# RT @gp_pulipaka: Ncrack: A High-Speed Network Cracking Tool. #BigData #Analytics #NoSQL #Redis #PostgreSQL #MongoDB #Networks #DataScience…
# RT @pycoders: Using Gitlab pipelines to deploy Python packages in production and staging environments – https://t.co/t7FOyJe5UQ
# RT @pycoders: Using Gitlab pipelines to deploy Python packages in production and staging environments – https://t.co/t7FOyJe5UQ
# RT @Ronald_vanLoon: 30 Free Courses: #NeuralNetworks, #MachineLearning, #Algorithms, #AI
# by @granvilledsc @geoff_hinton |
#
# Read more at htt…
# RT @pnique: No sé por qué estos días me ha venido a la memoria este fragmento de "Los caballeros de la mesa cuadrada" de Monty Python en el…
# イラスト書く友達がPython覚えるとかで非常にこの先が楽しみ
# RT @astroduff: Everyone interested in astro research should follow this lesson plan 👇 https://t.co/rooUXJaWCA
# Get started with blockchains and cryptocurrencies in Python. https://t.co/PqEM0iG5Jg
# RT @ramanuj_5: #Day2
# 1. Tried a problem on GeeksforGeeks, almost solved some minor test case still pending.
# 2. Learned more about python un…
# Want to contribute? To report a bug in the Python core, use the @ThePSF Python Bug Tracker: https://t.co/eh6XipkafH https://t.co/SnvAljVqqf
# RT @gp_pulipaka: Big Data and Container Orchestration with Kubernetes (K8s). #BigData #Analytics #MachineLearning #DataScience #AI #Python…
# @ThePSF : Python Ecuador meetup June 22 - https://t.co/fnRvBztSrw. topics covered: blockchain and cryptocurrencies,… https://t.co/TmfImnfJTg
# Five-Feet Long Python Rescued From House In Gurgaon - Eaves Rock || https://t.co/ipif47ceuT || #Cities
# RT Ronald_vanLoon "30 Free Courses: #NeuralNetworks, #MachineLearning, #Algorithms, #AI
# by granvilledsc geoff_hinto… https://t.co/Qis0d8gXaJ
# RT @ShaamiGomez: Los Simpsons, vengan de a uno https://t.co/3NxALZIL9T
# RT @BlackHatEvents: Details of a new exploit technique that can take advantage of 0-days in common frameworks written in Python, Ruby, Java…
# The AI tech talk is live now. join us to learn how to data cleansing and visualization, feature engineering using P… https://t.co/rgLG775cUJ
# #python
# RT @pirzadahannan: Son of a programmer!
# #webdeveloper #webdev #webdevelopment #WebsiteDesign #webcomic #programmer #code #Coding #FunniestT…
# Datasteward - Functioneel ontwerper (Python, Tibco Spotfire, ETL) - IJmuiden, Noord-Holland https://t.co/kYXYtvH1rb
# dash-core-components 0.25.0 #Python https://t.co/p7oODcZghx via @krachik
# Creating Mars-themed Apps with Python, Flask, Contentful and Twilio – Twilio Cloud Communications Blog… https://t.co/noUmwDoYth
# Five-Feet Long Python Rescued From House In Gurgaon - NDTV https://t.co/ZWlUwYf0qt #Gurgaon #News
# PyQ 未経験からのPython文法 Python初級[20. ユニットテストの基本]まで。409問中、277問修了。
# iselfを理解してない。あとユニットテスト自体をどういう時に使うのかイメージできてない。… https://t.co/uzy9wq3amo
# RT @dampenedkid: PyQ 未経験からのPython文法 Python初級[20. ユニットテストの基本]まで。409問中、277問修了。
# iselfを理解してない。あとユニットテスト自体をどういう時に使うのかイメージできてない。
#
# #100DaysOfCode…
# Want to contribute? To report a bug in the Python core, use the @ThePSF Python Bug Tracker: https://t.co/HbTyH7Pgho… https://t.co/BZDGTt1rdk
# [crypto] Get real time trading data using a Python and a Live DataFrame. https://t.co/qBiR6Vqmnd
# Fortnite: BR bot NEED HELP https://t.co/rhjRDmpIvA
# RT @kdnuggets: Basic #Image #DataAnalysis Using #Numpy and #OpenCV, Part 2 #Python #DataScience #DataVisualization https://t.co/s66Md6Jxty…
# Pink Floyd y Spinetta probablemente son geniales porque es lo que dicen casi todos, pero a mí me torran heavy. https://t.co/xa34gIuRB3
# Luis Miguel, Cristian Castro y sus derivados musicales.
# Lost.
# La cereza en todos lados. https://t.co/o8K8iQrG6O
# Python 3: Why is my prime sieve so slow? - https://t.co/ycKfS5ylpi
# @troIoIoIo @napalonywikary Pyton już podobno wyemigrował do UK i teraz to jest sir Python
# [0618_Programmatori Python e Javascript] at Metadonors https://t.co/z8f2zWscB9
# RT @dardo82: [0618_Programmatori Python e Javascript] at Metadonors https://t.co/z8f2zWscB9
# RT @spouyllau: Interroger @isidore___ avec du #SPARQL et créer avec #Python de petites visualisations des résultats, le tout dans #Jupyter…
# 😆😆. I can’t. https://t.co/todT7iLEG7
# RT @BakwasRadio: I like how they say 'the python was rescued' and not the Gurgaon family in the house https://t.co/lia1IrbkCo
# RT @LizekasFavour: This Jubrin Aminu using his kinsmen as bodyguards will that save him. God shall destroy his generation. Anything that ha…
# Want to contribute? To report a bug in the Python core, use the @ThePSF Python Bug Tracker: https://t.co/CZSzsNK2G6 https://t.co/6Xk5F4BbjZ
# @CamEdwards Try watching Monty Python now.... Not a laugh to be found
# RT @Bitbosecoin: Learn #Python #Bloackchain, #Docker, #WebVR from 𝑩𝑰𝑻𝑩𝑶𝑺𝑬 CTO @navdeepgarg at C# Corner Gurgaon Chapter Meet  On July 7!
# R…
# C'est @Veltingram qui commence, avec de la programmation fonctionnelle en python.
# Bir @YouTube oynatma listesine video ekledim: https://t.co/mlf5fGakcJ Çocuklar için Python - If - Else (Eğer - Değilse)
# RT @Ronald_vanLoon: 30 Free Courses: #NeuralNetworks, #MachineLearning, #Algorithms, #AI
# by @granvilledsc @geoff_hinton |
#
# Read more at htt…
# @sam_et_max Je vends mes services pour préparer vos applications à Python 4. Je vous préviens, la migration va être… https://t.co/IsaA0IFJje
# Urgent Need: Java/Python Architect https://t.co/1X1YmRLtg7
# Want to contribute? To report a bug in the Python core, use the @ThePSF Python Bug Tracker: https://t.co/UZVJgA5zT4 https://t.co/5aku2uza8R
# RT @Reza_Zadeh: AutoGraph generates TensorFlow graphs from arbitrary Python, supporting control flow such as while loops, if statements, br…
# Work started on 150.0 DAI (150.00 USD @ $1.0/DAI)
# https://t.co/K6ycAWlKSH  #py-walletconnect-bridge #walletconnect #python #shell
# RT @bbelderbos: Today I earned this @pybites certificate after coding a ton of #Python - join PyBites Code Platform and start coding! - htt…
# ふむ。まぁお気持ちの表明みたいだから、これから色々決めていく感じなんかな。→
# Python考案者のGuido van Rossum氏がPythonに関する意思決定から引退することを表明 | OSDN Magazine https://t.co/VjfNPzOKUP
# Juliaのコツがわかってきたので、リファクタリングして可読性爆上げした。
# プロット周り以外はpythonより柔軟に書けるようになった。
# scikit-learnだけはpythonから使いたいけど。
# @JayChamp16 Java? Python?
# RT @_wildoc_: Juliaのコツがわかってきたので、リファクタリングして可読性爆上げした。
# プロット周り以外はpythonより柔軟に書けるようになった。
# scikit-learnだけはpythonから使いたいけど。
# Hello,Python https://t.co/aYyVGIl2GJ
# 【ゼロから始める入門講座】やってみよ！python！
# https://t.co/X608HexEoC
# #udemy #クーポン #python
# Creo que de los meetups de PyData se hace cargo NumFocus.
# Desde pybonacci creo que poco podemos aportar.
# Desde… https://t.co/Mzj353kbYY
# Convert python code to TF symbolic code using just decorators! https://t.co/Xm09V7Mbfw
# @dan_gunter @find_evil @SubtleThreat @DragosInc Great work. I'd also point people to work by @williballenthin -… https://t.co/3dycAPrEMg
# RT @womenintechfund: We are very proud to announce that we have 10 entrance tickets for .@PyconGhana The Python Conference Ghana! which wil…
# New Competition! Fav, Follow and Retweet to win Billy Ocean's python-chucking Noxious Ponce Spank Mag #Verlosung https://t.co/DMalExWRoo
# RT @juanchocroppi96: Game of thrones https://t.co/tJSxqRu8R2
# Reading a theater history text I come across the following phrase on Roman theater, which somehow wasn't written by… https://t.co/RW3a5ktvCT
# 52. Monty Python's The Meaning of Life
# Dir. Terry Gilliam
#
# Unos sketches mejores que otros. En cierto punto me cans… https://t.co/lHY80zJhep
# Relative to my interests https://t.co/BdAxGSgKLI
# RT @ramanuj_5: #Day2
# 1. Tried a problem on GeeksforGeeks, almost solved some minor test case still pending.
# 2. Learned more about python un…
# RT @PyImageSearch: New video interview posted! 🚀 I sat down with @Raspberry_Pi + applied statistics expert, Jeff Bass, to discuss his work…
# Gah! I am task switching between emacs, arduino IDE, and Intellij... and java, C, and python. I am getting peanut b… https://t.co/5ZssadQ4n5
# Animation for an upcoming presentation of Jurriaan Schrofer's ‘illegible alphabet’, showing how the negative and po… https://t.co/FelDWgRSAF
# RT @Ronald_vanLoon: 30 Free Courses: #NeuralNetworks, #MachineLearning, #Algorithms, #AI
# by @granvilledsc @geoff_hinton |
#
# Read more at htt…
# Are you a #Python coder looking for onsite or remote opportunities? We have #techjobs across the country. Connect w… https://t.co/DqjaPQ9Ewz
# “7 features proposed so far in Python 3.8” by @anthonypjshaw https://t.co/s2t2uauTan
# @troIoIoIo @napalonywikary Nie każdy python może być monty
# Python 357　良い銃だ。オススメするぜ
# RT @DragosInc: In our newest blog, @Dan_Gunter and @SubtleThreat discuss how they open-sourced EvtxToElk, the Python module used to scale #…
# RT @Ronald_vanLoon: 30 Free Courses: #NeuralNetworks, #MachineLearning, #Algorithms, #AI
# by @granvilledsc @geoff_hinton |
#
# Read more at htt…
# RT @PythonParaguay: 🐍🇵🇾  PythonPy Meetup Julio 2018
#
# 📅 Viernes 20/07
# ⌚️ 19:30hs
# 📌 Codium (23 De Octubre 292)
#
# Charlas:
# ★ Julián Leguizamon:…
# @SybilleRompe @geor97 @Davidmetroland @asknbid @AwayFromTheKeys @Vikingavfc @Macid3000 @IrishEurophile… https://t.co/UwyKTj1nv8
# @StabbyCutyou That reminds me when I wrote Python in the beginning. Also wasted an hour or so because of a comma at… https://t.co/04Hle866yX
# Learn to Locate Elements Using Selenium Python #selenium #python https://t.co/pYXh1jGmHz
# Este programa tiene el mejor guionista de la TV Argentina. Debe ser uruguayo o uno de los Monty Python https://t.co/P47huhSROj
# -passes out and gets eaten by super long albino Burmese python-
# RT @blackgayvideo: Cop Fucker https://t.co/ntkTlNfQs4 Python &amp; Cristobal @videoboyblog #FreakSession https://t.co/lAn92eab0K
# Breaking bad https://t.co/FmX8Cu34Qj
# RT @EuropeOuul: Python Waterproof Stand - so much choice !! 👇 #ouul #ouuleurope https://t.co/lek8AdbEdE
# RT @eric_normandeau: [FR] Cours gratuit d'introduction à Python en ligne. Hautement recommendé pour ceux qui attendaient la bonne occasion…
# The latest The Django Daily! https://t.co/RO8UDauN8l Thanks to @pythontek1 @Froddie @CreoleSauvage #python #webdev
# https://t.co/izn7m6mTpv
# RT @gp_pulipaka: Serving #DeepLearning Models with #TensorFlow-Serving’s #RESTful #APIs. #BigData #Analytics #MachineLearning #DataScience…
# RT @guilhermejd1: Consulte CNPJs na Receita em python e sem captcha https://t.co/D4vtv1V3wV
# RT @dbader_org: 🐍🇩🇪 Die deutsche Version von "Python Tricks" erscheint am 31. Juli! Vorbestellen ist hier möglich: https://t.co/AI8HB9ApZG…
# Cerveza 😈 https://t.co/G0jlm80qav
# RT @BlackHatEvents: Details of a new exploit technique that can take advantage of 0-days in common frameworks written in Python, Ruby, Java…
# Join the live webinar with MapD's @randyzwitch now!
# @pfreixes @pablitoev56 Has been at least a couple of years since I profiled serialization. Anyhow check that ujson… https://t.co/bLkguDOskZ
# RT @ewa_jodlowska: This is a great way to recognize Pythonistas from **all over the world**. If you know a Pythonista that is helping our c…
# Python Application Development Using Imbalanced-learn 🔗 https://t.co/FES5bXtlJA
# RT @mad_liberals: In celebration of my first blue check follower! @RealAlexJones
#
# Here's Monty Python And the Holy Trump video, featuring…
# Remove some of that friction and smoothly pass algorithms from data scientist to developer with ActivePython in thi… https://t.co/AWfMVN9xu4
# RT @omidbiz: https://t.co/izn7m6mTpv
# All I want to do is learn all the languages, but can’t sit on just one.. I’m currently expanding my JavaScript know… https://t.co/5S8Zkd9AFW
# MONTY PYTHON’S LIFE OF BRIAN (1979)
#
# DP: Peter Biziou
# Dir: Terry Jones
# Buy or Rent via Amazon:… https://t.co/VAj6iQhXcX
# ...
# @caangriman @GustArballo @amapolas35 Tranquilo señor. Entiendo esa cosa que se genera, tipo negación, cuando se va… https://t.co/iK5gKEqBZA
# RT @joelgrus: *always* type-annotate your Python
#
# the cost to you is minimal (you have to type a few extra characters)
#
# the benefits to you…
# RT @Rwaq: مازال بإمكانك الالتحاق بالمادة المجانية في رواق للتعرف على علم البيانات باستخدام Python مع حصولك على شهادة في نهاية الدورة.
#  ابدأ…
# I just published “Dependency Injection: Python” https://t.co/Kfqq1CdA4b
# RT @OnePerfectShot: MONTY PYTHON’S LIFE OF BRIAN (1979)
#
# DP: Peter Biziou
# Dir: Terry Jones
# Buy or Rent via Amazon: https://t.co/R06slu9JN…
# "When your coding in #Python, you are riding in a Maybach" - @raymondh (there was way more to this story but alas,… https://t.co/WZ8T68KUtC
# Day 112: #100DaysOfCode progress: trying to make an app for commercial use/sell. So far went smooth but shouldn't h… https://t.co/c7y3fFVRFo
# How virtual environment libraries work in Python – https://t.co/vdABEw9kHP
# RT @devtazv2: Day 112: #100DaysOfCode progress: trying to make an app for commercial use/sell. So far went smooth but shouldn't have change…
# RT @devtazv2: Day 112: #100DaysOfCode progress: trying to make an app for commercial use/sell. So far went smooth but shouldn't have change…
# RT @waterlego: If you use #python, you'll probably want to bookmark this page: 'Awesome Python', a curated list of awesome Python framework…
# VRCMS club member Steve Davis is excited to show off his brand new 100cc Pitts Python at the Airshow!  Pretty fancy… https://t.co/uDvMlSpCAp
# I've spent almost all day trying to get a Taylor diagram to work with python. This is way too much statistics for m… https://t.co/QNiVmJJJy5
# Utiliza #Python con #Arduino: Configuración comunicaciones serie entre Arduino y Python: https://t.co/ae2hdsayYM via Polaridad
# RT @ykdojo: I asked my Twitter and LinkedIn followers for book recommendations for Python beginners. Here are the 3 top recommendations I g…
# RT @pycoders: How virtual environment libraries work in Python – https://t.co/vdABEw9kHP
# RT @SAA_ERS: Alejandra Dean of the Massachusetts Archives @SecretaryOfMass kicks off  our “Script It!” Series! Learn how she used Python to…
# .@ApostleLeGrand on #Periscope: Python spirit https://t.co/LMrqOOsKmW
# Python: Logistic Regression https://t.co/V29N4eEhtI #analytics #Datascience #MachineLearning #Statistics
# RT @Zerynth: #Zerynth r2.1.2 is out with support for @xinaboxcc CW02, @MicrochipTech Xplained Pro Sam G55 and Redeem Licenses.
# Check out al…
# RT @ArkEcosystem: With a new #ARK Core comes newly coded #SDK's as well, completely restructured and written from scratch.
#
# https://t.co/mx…
# Fedora 28 Update: python-rpm-macros-3-30.fc28 https://t.co/JVD5KWdm9h
# RT @OnePerfectShot: MONTY PYTHON’S LIFE OF BRIAN (1979)
#
# DP: Peter Biziou
# Dir: Terry Jones
# Buy or Rent via Amazon: https://t.co/R06slu9JN…
# RT @LittleAirshow: VRCMS club member Steve Davis is excited to show off his brand new 100cc Pitts Python at the Airshow!  Pretty fancy, eh?…
# Sr #Python #Developer/ Architect- C2C/ C2H/ Full Time - JM Information Systems - [ 📋 More Info… https://t.co/DRsklok7Gv
# RT @hanoverrec: Exciting #opportunity for a #Python #developer to join an #award winning #digital agency with a progressive culture, offeri…
# RT @armaninspace: A simple neural network with #Python and Keras https://t.co/cOlCNdz00F
# Are you going to the East Bay #Python Web Development meetup tomorrow? Info: https://t.co/CLg6BX7cu3
# Mc Donald's. https://t.co/E3BYS4jwT3
# RT @LittleAirshow: VRCMS club member Steve Davis is excited to show off his brand new 100cc Pitts Python at the Airshow!  Pretty fancy, eh?…
# Matlab Gurgaon hai toh even that python had to be ‘rescued’. Anywhere else the headline would’ve read ‘python terro… https://t.co/KDLb9ZO1jq
# RT @osdn_magazine: https://t.co/VUaA0LvcPD #osdn #osdn_magazine #sfjp #sfjp_magazine Python考案者のGuido van Rossum氏がPythonに関する意思決定から引退することを表明
# RT @realtoughcandy: It's OK to quit.
# WOAH. WHAT?
# https://t.co/c3JolUKpWx
#
# #webdevelopment #code #coding #codenewbie #programming #javascrip…
# RT @yvNSHhtHVBRK7j5: python勉強中に「あれッ？低水準言語の方がよくね？」
# ｃ++勉強中に「あれッ？言語よりアルゴリズムじゃね？」
# アルゴリズム勉強中に「あれッ？数学も必要じゃね？」←今ココ
# RT @_qaz_qaz: CPython internals: A ten-hour codewalk through the Python interpreter source code
#
# https://t.co/LN4Ng7VkWd
# Involved residents rescue 10m-long python runover by automotive [Video] https://t.co/66Ks6DB1hk
# RT @pycoders: How virtual environment libraries work in Python – https://t.co/vdABEw9kHP
# Chocolate https://t.co/Xb6RGKcR1A
# @elgolfo Deja checo, pero sí es un gran disco, está padre que ya hay más híbridos del dembow con otras cosas: Dj Py… https://t.co/SmhLKWOP87
# Monty python ❤❤ https://t.co/thMF9De6Je
# 📌30_days_of_data
# Day 9 of 30 days Challenge!!
# 🌹: Finished lessons on error handling in python lesson 27.
#
# 🌵:Attempt… https://t.co/SaGN9MITsl
# Excellent talk on UMAP for dimensionality reduction (clustering) by @leland_mcinnes at #SciPy2018:… https://t.co/PLmxAXvdpf
# RT @KiliJerez: Los simpsons https://t.co/wSsAAdK2HF
# RT @AlenaPiksaeva: #100DaysOfCode Day 12. Getting so much better at #Python! The most amazing feeling is when things start to make sense. #…
# You surrounded by snakes https://t.co/9VZa0g4zZ7
# @StabbyCutyou It's always the little things that trip you up, don't come much smaller than a . Usually a ; for me : if it's python.
# New #TensorFlow feature converts #Python code, including control flow, print() and other Python-native features, in… https://t.co/dygsb1BsEb
# @dr_ayshah @AlRiyadh Python Fundamentals Wesley Chun 2009
# los gatos https://t.co/uI26htuXeF
# C'est quoi l'utilité des tuples par rapport aux listes en python ?
# Est-ce que ça sert vraiment à quelque chose ? (… https://t.co/ALSIAerAWm
# @matheoxz AMEI e eu enrolando pra fazer aquele único de Python KWBQKSBQK
# RT @yvNSHhtHVBRK7j5: python勉強中に「あれッ？低水準言語の方がよくね？」
# ｃ++勉強中に「あれッ？言語よりアルゴリズムじゃね？」
# アルゴリズム勉強中に「あれッ？数学も必要じゃね？」←今ココ
# RT @RSComponents: Speed up your #IoT development thanks to our new partnership with @Zerynth. Easily program popular microcontrollers in #P…
# RT @devtazv2: Day 112: #100DaysOfCode progress: trying to make an app for commercial use/sell. So far went smooth but shouldn't have change…
# Game of thrones
# Salsas en hamburguesa
# Reggaeton https://t.co/VccTOKaROe
# So much of comedy ages incredibly badly. It feels like our taste in what's funny changes really drastically over ti… https://t.co/OAwfoVxG5b
# Your secret will unmake the world.
# You didn't mean to mix elements of python and java in such a way that the AI of… https://t.co/R5EKNjUl7S
# RT @ClintonBrownley: @NumFOCUS Projects at @SciPyConf 2018
# Talks and videos and tutorials, oh my! #Python #Julia
# https://t.co/JI3A4ikRGC ht…
# RT @ArkEcosystem: With a new #ARK Core comes newly coded #SDK's as well, completely restructured and written from scratch.
#
# https://t.co/mx…
# Cerveza. https://t.co/bfU4PwZipr
# RT @ArkEcosystem: With a new #ARK Core comes newly coded #SDK's as well, completely restructured and written from scratch.
#
# https://t.co/mx…
# RT @ArkEcosystem: With a new #ARK Core comes newly coded #SDK's as well, completely restructured and written from scratch.
#
# https://t.co/mx…
# @gocall01 I ran a Python script to scrape all the #SFB8 drafts and then I just check how many people took that play… https://t.co/LZRQuZjnaO
# RT @Bitbosecoin: Learn #Python #Bloackchain, #Docker, #WebVR from 𝑩𝑰𝑻𝑩𝑶𝑺𝑬 CTO @navdeepgarg at C# Corner Gurgaon Chapter Meet  On July 7!
# R…
# Welcome to the world of Python.. https://t.co/TqhyDsmakl
# Stealing an idea from @BarrasaDV  - QuickGraph: Analysing #Python Dependency Graph with PageRank, Closeness Central… https://t.co/U1K5Wo4l9d
# RT @CodeAgora: We're Hiring!
#
# Specialised Instructors Wanted:
# Front-end Web Development, Back-end Web Development (PHP, Python and MySQL) a…
# Here here @Python #PyPi package maintainers ........ https://t.co/ZADjpsCJGc
# RT @teoliphant: Excellent talk on UMAP for dimensionality reduction (clustering) by @leland_mcinnes at #SciPy2018: https://t.co/HSkZUUEx0y.…
# Osnovni kurs programiranja za osnovce i srednjoškolce u Startit centru u Inđiji u programskom jeziku Python trajaće… https://t.co/nfNoCFbVXN
# @Ronald_vanLoon Posted...
# https://t.co/DoE3kz9wdp
# RT @teoliphant: Excellent talk on UMAP for dimensionality reduction (clustering) by @leland_mcinnes at #SciPy2018: https://t.co/HSkZUUEx0y.…
# RT @albertcardona: Just updated the python @FijiSc tutorial with #imglib2 examples to transform images.
#
# While these examples barely scratc…
# #Python #Developer, London. - Synergetic Recruitment Group Limited - [ 📋 More Info  https://t.co/ybIo662rIQ ]… https://t.co/swFRYmhw0e
# RT @IgboNative: 2019 Python dance will be for everybody, since we allowed our hate and tribalism blind us in kicking away the only democrac…
# RT @ykdojo: I asked my Twitter and LinkedIn followers for book recommendations for Python beginners. Here are the 3 top recommendations I g…
# @DrFrancesRyan Monty Python cheese shop sketch realised at last!  Brought to you by Brexit!!!
# RT @TensorFlow: Graph models allow for all kinds of optimization, but it can be tricky to move between Python and graph code. To help with…
# TensorBeat: New #TensorFlow feature converts #Python code, including control flow, print() and other Python-native… https://t.co/yL5uWFYwzB
# RT @ArkEcosystem: With a new #ARK Core comes newly coded #SDK's as well, completely restructured and written from scratch.
#
# https://t.co/mx…
# RT @SanaBenzi: Big Data and Container Orchestration with Kubernetes (K8s). #BigData #Analytics #MachineLearning #DataScience #AI #Python #R…
# Eu tô dando explicação de Python em grupo e slack. Me.l sinto inteligente ahahhahaha
# Saturday Night Live, no me saca una sonrisa. https://t.co/1OCpfYtiCR
# Maintain a #Python package on #PyPi? Read and do this please! https://t.co/2cjeJZijX4
# Ready Player One references the Holy Hand Grenade from Monty Python and The Holy Grail. I obviously didn't know wha… https://t.co/c38wHGWsW2
# RT @CoreBiafran: #BuhariInHague! Arrest Him Now! Evil Man Goes To Netherland 🇳🇱, The Home Of ICC @IntlCrimCourt
# Pres Jubril Buhari Is In Ha…
# Slightly changed and repainted Python and sawed-off. I think these colours are more suitable https://t.co/obIV6WSAH1
# Nueva oportunidad de empleo SR / SSR Software Engineer in Test - Performance: https://t.co/H7Nbi2RABR #Empleo… https://t.co/UmNtyyxnWj
# RT @jcldf: A simple python script that generates random HTTP/DNS traffic noise in the background while you go about your regular web browsi…
# @NArs80 @umairjav Recently read his autobiography and seems the religious extremism was always there. Says he under… https://t.co/dgGJqE9N2O
# @RyoSJA71AN Pythonは訳すとニシキヘビのことだけど、プログラミング言語でもあるよ。プログラミング言語の中ではRubyと並んで最も簡単な言語の一つだよ。プログラミングコード自体がシンプルで分かりやすい。あとPytho… https://t.co/Ek3pE9tPdi
# Is forsyth in FEH yet? Is Python in FEH yet?
# RT @k4nd4lf: Hello freelancers in my network! Anyone interested in some #Remote Python work / support for about 4 weeks in mid August?. Ple…
# RT @TensorFlow: Graph models allow for all kinds of optimization, but it can be tricky to move between Python and graph code. To help with…
# RT @python_tip: You most likely know about 'global' and 'local' variables but do you know 'nonlocal'?
#
# https://t.co/rmQjUgUKfZ
# https://t.co…
# Sounds incredibly useful https://t.co/MJAH9u3xi3
# RT @guilhermejd1: Consulte CNPJs na Receita em python e sem captcha https://t.co/D4vtv1V3wV
# RT @Bitbosecoin: Learn #Python #Bloackchain, #Docker, #WebVR from 𝑩𝑰𝑻𝑩𝑶𝑺𝑬 CTO @navdeepgarg at C# Corner Gurgaon Chapter Meet  On July 7!
# R…
# @StabbyCutyou @nixcraft As a python programmer, my fingers prefer to type lamdba and my brain can't see the difference.
# @Michielstock Julias multiple dispatch makes it easy to write code that specializes on types. It is easy to not not… https://t.co/VLEVRgRAeH
# RT @pycoders: How virtual environment libraries work in Python – https://t.co/vdABEw9kHP
# RT @LucioSchAuna: Jugar al truco❌ https://t.co/iqXt0XvmTJ
# RT @ArkEcosystem: With a new #ARK Core comes newly coded #SDK's as well, completely restructured and written from scratch.
#
# https://t.co/mx…
# Why is #Python so slow? - @anthonypjshaw https://t.co/99bphsTEY2 #Programming #Python #Software #Development… https://t.co/L59l9PqzjM
# RT @newentschool: Thank you @ThinkITprocure. If any school wishes to learn about this work please contact us.  We are happy to talk and sha…
# casados con hijos https://t.co/e7Rk7TPVh1
# RT @freddy1876: Basic Statistics in Python: Probability https://t.co/elYD27i8Vv https://t.co/Jsh1iOPaLs
# @shiraponsu プロフみたところ、人にプログラムを教えるときの注意点とか、pythonとか、色々お持ちな気がしました！
# RT @ArkEcosystem: With a new #ARK Core comes newly coded #SDK's as well, completely restructured and written from scratch.
#
# https://t.co/mx…
# RT @ArkEcosystem: With a new #ARK Core comes newly coded #SDK's as well, completely restructured and written from scratch.
#
# https://t.co/mx…
# @WebGo3 #codepen #wplife #Javascript #developer #java #php #instagood #i❤python #python #vscode #node #code… https://t.co/qahRfgn31Z
# python3-indy 1.5.0-dev-631 https://t.co/uZKftJv09M
# @WebGo3 #codepen #wplife #Javascript #developer #java #php #instagood #i❤python #python #vscode #node #code… https://t.co/3MGruS4hCz
# This Hours Photo: #weather #minnesota #photo #raspberrypi #python https://t.co/qV4GI1mI1w
# RT @FlashgitzTom: So much of comedy ages incredibly badly. It feels like our taste in what's funny changes really drastically over time.
#
# T…
# May be data encryption is going on...🤔 @mohitkm94
# #coffee #coding #programming #programmer #developer #coder #java… https://t.co/OKpt3Nsc2h
# Naveen K Gupta: Learn &amp; Earn – https://t.co/GBBYnetOQq ,#Brokerage #Nifty #Daily #SwingTrading #ZBizExclusive… https://t.co/KLA6KnojnM
# RT @markhneedham: Stealing an idea from @BarrasaDV  - QuickGraph: Analysing #Python Dependency Graph with PageRank, Closeness Centrality, a…
# So happy to announce the release of this course! I hope folks enjoy it. https://t.co/oN2OttyAgL
# RT @ArkEcosystem: With a new #ARK Core comes newly coded #SDK's as well, completely restructured and written from scratch.
#
# https://t.co/mx…
# Working through this fantastic ML course by @AndrewYNg (thank you!) on @coursera - octave is good, but I am more co… https://t.co/qYNikQrXQX
# python-bogus-project-honeypot 1531939498.3 https://t.co/CWPFkl5Pgt
# RT @Reza_Zadeh: AutoGraph generates TensorFlow graphs from arbitrary Python, supporting control flow such as while loops, if statements, br…
# RT @freakboy3742: A huge *thank you* to @gvanrossum for everything he’s done for the Python community. I can’t understate how profound your…
# @CBCPolitics @BillBlair The Minister of Irregularity. Very Monty Python..ish. 😁 #cdnpoli
# RT @teoliphant: Excellent talk on UMAP for dimensionality reduction (clustering) by @leland_mcinnes at #SciPy2018: https://t.co/HSkZUUEx0y.…
# RT @ArkEcosystem: With a new #ARK Core comes newly coded #SDK's as well, completely restructured and written from scratch.
#
# https://t.co/mx…
# RT @ArkEcosystem: With a new #ARK Core comes newly coded #SDK's as well, completely restructured and written from scratch.
#
# https://t.co/mx…
# Retweeted https://t.co/v3saOo2kvb (@ArkEcosystem):
#
# With a new #ARK Core comes newly coded #SDK's as well, complete… https://t.co/Vowc4HUpYz
# RT @yahova: Retweeted https://t.co/v3saOo2kvb (@ArkEcosystem):
#
# With a new #ARK Core comes newly coded #SDK's as well, completely restructu…
# RT @ArkEcosystem: With a new #ARK Core comes newly coded #SDK's as well, completely restructured and written from scratch.
#
# https://t.co/mx…
# RT @ykdojo: I asked my Twitter and LinkedIn followers for book recommendations for Python beginners. Here are the 3 top recommendations I g…
# #neo4j RT markhneedham: Stealing an idea from BarrasaDV  - QuickGraph: Analysing #Python Dependency Graph with Page… https://t.co/ZghYwPx70q
# RT @robintiwari: GitHub launches security alerts for #Python https://t.co/z6Xru9IHu5 @pythonbytes
# RT @SanaBenzi: Big Data and Container Orchestration with Kubernetes (K8s). #BigData #Analytics #MachineLearning #DataScience #AI #Python #R…

# %% [markdown]
# Can you adapt this code block to search for another hashtag?

# %% [markdown]
# In this workshop, we have executed all our Python code in a so-called IPython notebook (for more information, see [http://jupyter.org/](http://jupyter.org/)). However, many developers prefer to use the command line for executing small scripts. In what follows, I will show you how we can scrape tweets from Twitter using the command line.

# %% [markdown]
# You have already used the command line to launch the IPython notebook of this workshop and we will use the same application to run a Python script. First, launch a new terminal (on Linux or Mac OS X) or command prompt (on Windows). Second, move to the folder in which you saved the current workshop. For Mac OS X and Linux users:

# %% [markdown]
#     cd ~/Desktop/twitter-workshop-master

# %% [markdown]
# For Windows users:

# %% [markdown]
#     cd c:\Users\your-user-name\Desktop\twitter-workshop-master

# %% [markdown]
# Replace `your-user-name` in the path above with your actual user name. The folder `twitter-workshop-master` contains a file named `tweetscraper.py`, which is a Python script to scrape tweets from Twitter. Python scripts can be executed from the command line/ prompt by issuing:

# %% [markdown]
#     python name-of-script.py [arguments]

# %% [markdown]
# In our case, this means that we can execute the tweet-scraper by issuing:

# %% [markdown]
#     python tweetscraper.py

# %% [markdown]
# The tweet-scraper script takes two arguments. The first argument is the path to the directory in which you want to save the streamed tweets. The second argument is the search query, with which you specify one term or multiple terms that must be present in a tweet. To execute the `tweetscraper.py` script, issue the following command:

# %% [markdown]
#     python tweetscraper.py -d data -q lunch

# %% [markdown]
# Your terminal or command prompt should look similar to:

# %% [markdown]
# ![](images/commandline.png)

# %% [markdown]
# Open your file browser and watch the file names `stream_lunch.json` grow. To stop the script from streaming, hold `ctrl` and press `c`. To finish this section, try searching for another term or terms.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Now that we have created a small application to scrape tweets from Twitter, let us move to the second part of this workshop, in which we will perform some text preprocessing steps we need for textual analysis.

# %% [markdown]
# Let us first have a look at the structure of a tweet. We saved our tweets in the `data/` folder under the name `stream_[QUERY].json`, where query should be replaced with the query you searched for. The tweets are formatted in JSON, which is a common data structure to store data on the Internet. Let's have a look at the structure of a single tweet:

# %%
import json

with open("stream_lunch.json") as infile:
    line = infile.readline()
    tweet = json.loads(line)
    print(json.dumps(tweet, indent=4))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-722f212f2938> in <module>()
#       1 import json
#       2
# ----> 3 with open("stream_lunch.json") as infile:
#       4     line = infile.readline()
#       5     tweet = json.loads(line)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'stream_lunch.json'

# %% [markdown]
# As you can see, a tweet contains quite a lot of information about, for example, the geolocation, the date, the tweeter, etc. The most important fields for our purposes are:

# %% [markdown]
# 1. text: the text of the actual tweet;
# 2. created_at: the date of creation;
# 3. favorite_count: the number of favorites of this tweet;
# 4. retweet_count: the number of retweets;
# 5. lang: the language of the tweet;
# 6. id: the tweet identifier;
# 7. place: geo-location information;
# 8. user: the profile of the author of the tweet.

# %% [markdown]
# The JSON format is quite convenient for doing computational analyses, but often we would like to manually inspect the data. Unfortunately, JSON is not the most readable format. Therefore, in what follows we will convert our scraped tweets into an CSV (comma separated value) file, which you can open and modify using familiar software such as Excel. The following code block shows you how to do that in only a few lines of code:

# %%
import csv

fields = ['id', 'created_at', 'user', 'text', 'favorite_count', 'retweet_count', 'lang', 'place']

tweets = []
with open("data/stream_lunch.json") as infile:
    for line in infile:
        tweet = json.loads(line)
        information = []
        for field in fields:
            if field not in tweet:
                information.append('')
            elif field == 'user':
                information.append(tweet['user']['name'])
            elif field == 'place' and tweet['place'] != None:
                information.append(tweet['place']['name'])
            else:
                information.append(tweet[field])
        tweets.append(information)

with open("data/stream_lunch.csv", "w") as outfile:
    csvwriter = csv.writer(outfile)
    csvwriter.writerow(fields) # write the field names as header
    csvwriter.writerows(tweets)

# %% [markdown]
# In this code block, the variable `fields` is a list, which indicates the fields of the tweets we want to store in our CSV-file. Can you update this list with some other fields?

# %% [markdown]
# The folder of this workshop contains another Python script named `json2csv.py`, which can be used to convert a file of tweets in JSON format to a CSV file. Again, this script needs to be executed from the command line/ prompt. It takes two arguments: the input file (i.e. the json file containing our tweets) and the output file (i.e. the filename of our new CSV file):

# %% [markdown]
#     python json2csv.py --infile [PATH TO YOUR JSON FILE] --outfile [PATH TO YOUR CSV FILE]

# %% [markdown]
# Can you update this line with the correct paths to both the JSON file and the new CSV file and execute it in your terminal or command prompt. After that, open the CSV file with Excel or some other spreadsheet program.

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# After we have collected and preprocessed our data, let us move on to the final part of this workshop, which we will start digging into some aspects of data visualization.

# %% [markdown]
# There are many libraries available in Python for doing data visualization. The backbone of most of these libraries is the acclaimed plotting library [Matplotlib](http://matplotlib.org/). Matplotlib provides almost all functionality to make the fancy graphs you always dreamed of. The default color schemes of this library, however, don't look really pretty ([although people are working on this](http://bids.github.io/colormap/)). I therefore generally resort to [Seaborn](https://stanford.edu/~mwaskom/software/seaborn/index.html) or to the interactive plotting library [Bokeh](http://bokeh.pydata.org/en/latest/) when doing data visualization. In this workshop, we will have a brief look at some of the plotting functionality in Seaborn.

# %% [markdown]
# We start with importing the library into our notebook:

# %%
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# After that we can create simple plots such as:

# %%
sns.plt.plot(range(10))

# %% [markdown]
# Or:

# %%
import numpy as np

t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2 * np.pi * t)
sns.plt.plot(t, s)

sns.plt.xlabel('time (s)')
sns.plt.ylabel('voltage (mV)')
sns.plt.title('About as simple as it gets, folks')

# %% [markdown]
# Let us now try something more interesting: can we visualize our scraped twitter stream as a timeline, in which we can observe the rise and fall of a particular topic on Twitter? Creating such a timeline involves the following steps. First we need to load our CSV file into Python. The third-party library [Pandas](http://pandas.pydata.org/) provides excellent functionality to work with CSV files. By executing the following cell, we load all our data into Python:

# %%
import pandas as pd
data = pd.read_csv("data/stream_lunch.csv", parse_dates=['created_at'], index_col='created_at').sort_index()
data.head()

# %% [markdown]
# Second, we plot the timeline using:

# %%
data.text.notnull().resample("1T").sum().plot()

# %% [markdown]
# Just as we expected... In the code block above, I resample the data into 1 minute bins and count how often the timestamps fall into a bin. Try changing `1T` into `3T` and see what happens when you execute the code block again.

# %% [markdown]
# Let's make some other time series plots, which give a more detailed view on what people are discussing. For illustration purposes, let find out how if and when people are tweeting about a sandwich:

# %%
data.text.str.contains("sandwich").resample("1T").sum().plot()

# %% [markdown]
# Or simply a snack:

# %%
data.text.str.contains("snack").resample("1T").sum().plot()

# %% [markdown]
# These plots can be combined into a single plot by executing the two lines within the same cell:

# %%
data.text.str.contains("snack").resample("1T").sum().plot()
data.text.str.contains("sandwich").resample("1T").sum().plot()
data.text.str.contains("food").resample("1T").sum().plot()

sns.plt.legend(["snack", "sandwich", "food"])

# %% [markdown]
# The folder of this workshop contains another Python script named `visualizetweets.py`, with which you can create these time series plots from the command line. The script takes 3 arguments: (i) the CSV file containing the tweets, (ii) the way you want to resample and aggregate your data (e.g. into bins of 1 minute, etc.) and (iIi) the terms you want to plot. If you don't specify any terms, the script will simply produce a time series plot of all tweets. The script can be executed as follows:

# %% [markdown]
#     python visualizetweets.py --infile [PATH TO YOUR CSV FILE] --resample [RESAMPLE METHOD] --query [TERM OR TERMS]

# %% [markdown]
# Update the various arguments and try executing this command. After that, open the data folder of this workshop and open the file named "tweetviz.pdf".
